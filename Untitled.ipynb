# %%
dbx = pandas.read_excel("Colleges SAT GT 1300.xlsx", sheet_name = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-08f7e441de7a> in <module>
# ----> 1 dbx = pandas.read_excel("Colleges SAT GT 1300.xlsx", sheet_name = 0)
#
# NameError: name 'pandas' is not defined

# %%
import pandas

# %%
dbx = pandas.read_excel("Colleges SAT GT 1300.xlsx", sheet_name = 0)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-08f7e441de7a> in <module>
# ----> 1 dbx = pandas.read_excel("Colleges SAT GT 1300.xlsx", sheet_name = 0)
#
# ~/.local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.9/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
# ...

# %%
import openpyxl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-f5ea1cbb6934> in <module>
# ----> 1 import openpyxl
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
import openpyxl

# %%
dbx = pandas.read_excel("Colleges SAT GT 1300.xlsx", sheet_name = 0)

# %%
dbx
# Out:
#      UNITID      OPEID   OPEID6  \
# 0    100706   105500.0   1055.0
# 1    107080   109900.0   1099.0
# 2    110404   113100.0   1131.0
# 3    110422   114300.0   1143.0
# 4    110635   131200.0   1312.0
# ..      ...        ...      ...
# 106  243780   182500.0   1825.0
# 107  245652   209300.0   2093.0
# 108  399911  3814400.0  38144.0
# 109  482936  4263400.0  42634.0
# 110  166629        NaN      NaN
#
#                                                 INSTNM             CITY  \
# 0                  University of Alabama in Huntsville       Huntsville
# 1                                      Hendrix College           Conway
# 2                   California Institute of Technology         Pasadena
# 3    California Polytechnic State University-San Lu...  San Luis Obispo
# 4                    University of California-Berkeley         Berkeley
# ..                                                 ...              ...
# ...

# %%
dbf = dbx.loc["Colorado School of Mines", "UNITID":"CONTROL"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-41d28014927e> in <module>
# ----> 1 dbf = dbx.loc["Colorado School of Mines", "UNITID":"CONTROL"]
#       2
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
#
# ...

# %%
dbf = dbx.iloc[0, 1:4]

# %%
dbf
# Out:
# OPEID                                105500.0
# OPEID6                                 1055.0
# INSTNM    University of Alabama in Huntsville
# Name: 0, dtype: object

# %%
dbx.iloc[0, 1:4]
# Out:
# OPEID                                105500.0
# OPEID6                                 1055.0
# INSTNM    University of Alabama in Huntsville
# Name: 0, dtype: object

# %%
dbf = dbx.iloc[0, :]

# %%
dbf.loc[{"UNITID","INSTNM", "CITY", "CONTROL", "CCBASIC", "CCUGPROF", "ADM_RATE_ALL", "SATVR75", "SATMT75", "SATMTMID", "SAT_AVG_ALL", "UGDS", "UGDS_WHITE", "UGDS_ASIAN", "TUITIONFEE_IN", "TUITIONFEE_OUT"}]
# Out:
# CCBASIC            16-Doctoral Universities: High Research Activity
# ADM_RATE_ALL                                                 0.8257
# UGDS_WHITE                                                   0.7161
# TUITIONFEE_IN                                                 11122
# UGDS_ASIAN                                                   0.0347
# CITY                                                     Huntsville
# UGDS                                                           7785
# SATVR75                                                         720
# SAT_AVG_ALL                                                    1319
# TUITIONFEE_OUT                                                23518
# INSTNM                          University of Alabama in Huntsville
# UNITID                                                       100706
# SATMT75                                                         770
# CONTROL                                                  1 - Public
# ...

# %%
inpu
